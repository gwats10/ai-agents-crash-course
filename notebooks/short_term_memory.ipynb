# %% [markdown]
# # Short-Term Memory

# %%
import dotenv
from agents import Agent, Runner, SQLiteSession, trace

dotenv.load_dotenv()
# Out:
# True

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
)

# %% [markdown]
# ## No Memory

# %%
result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")
print(result.final_output)
# Out:
# 1) Bananas: 8/10 - Nutrient-dense (dietary fiber, potassium, vitamins); natural sugars but come with minerals and fiber.
# 2) Lollipop: 2/10 - Mostly sugar with little to no nutrients; quickly raises blood sugar.

# %%
result = await Runner.run(nutrition_agent, "Add apples to the comparison")
print(result.final_output)
# Out:
# I’m missing the other foods in the comparison. Which foods should I compare alongside apples?
#
# If you want a quick example, here’s a baseline with apples included:
# - Apples: 7/10
# - Carrots: 8/10
# - Oats: 9/10
# - Almonds: 8/10
# - Blueberries: 9/10
#
# Tell me the exact foods to compare and I’ll rank them.

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?"
)
print(result.final_output)
# Out:
# 1) Banana: 8/10 - nutrient-dense (potassium, fiber, vitamins), natural sugars, healthful overall.
# 2) Lollipop: 2/10 - mainly sugar, few nutrients, empty calories.

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison"
    )

print(result.final_output)
# Out:
# I’m missing the other foods to compare apples with. Which foods should I include alongside apples? If you’d like, I can compare apples with common options (e.g., bananas, oranges, cookies) once you specify.
